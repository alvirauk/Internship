# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('happiness_score_dataset.csv')

# %%
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
df.tail()
# Out:
#      Country                           Region  Happiness Rank  \
# 153   Rwanda               Sub-Saharan Africa             154
# 154    Benin               Sub-Saharan Africa             155
# 155    Syria  Middle East and Northern Africa             156
# 156  Burundi               Sub-Saharan Africa             157
# 157     Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 153            3.465         0.03464                   0.22208  0.77370
# 154            3.340         0.03656                   0.28665  0.35386
# 155            3.006         0.05015                   0.66320  0.47489
# 156            2.905         0.08658                   0.01530  0.41587
# 157            2.839         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 153                   0.42864  0.59201                        0.55191
# ...

# %%
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isin(['?','-',' ','NA','NaN']).sum().any()
# Out:
# False

# %%
df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
df.nunique()
# Out:
# Country                          158
# Region                            10
# Happiness Rank                   157
# Happiness Score                  157
# Standard Error                   153
# Economy (GDP per Capita)         158
# Family                           158
# Health (Life Expectancy)         157
# Freedom                          158
# Trust (Government Corruption)    157
# Generosity                       158
# Dystopia Residual                158
# dtype: int64

# %% [markdown]
# #Here looking at the unique values - I am going to treat Happiness score as my target variable - I am also confirming this via looking at the number of unique values - my target variable is also numeric continous variable.

# %%
df.describe(include= object)
# Out:
#             Country              Region
# count           158                 158
# unique          158                  10
# top     Switzerland  Sub-Saharan Africa
# freq              1                  40

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
df.shape
# Out:
# (158, 12)

# %%
df.replace([np.inf, -np.inf], np.nan, inplace=True)  # Replace infinities with NaN
df.dropna(inplace=True)

# %%
A =df.sort_values(by='Happiness Rank', ascending=True).head(5)

# %%
A
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
Here we can see that the top 5 countries with the highest happiest rank are the european countries. The highest happiest score is 7.5 for Switzerland.
# Out:
#   Cell In[17], line 1
#     Here we can see that the top 5 countries with the highest happiest rank are the european countries. The highest happiest score is 7.5 for Switzerland.
#          ^
# SyntaxError: invalid syntax

# %%
B =df.sort_values(by='Happiness Score', ascending=False).head(5)

# %%
B

# %%
C =df.sort_values(by='Happiness Score', ascending=False).tail(5)

# %%
C
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 C
#
# NameError: name 'C' is not defined

# %% [markdown]
# #Here we can see that the lowest score - in terms of the happiness score is 2.83 for Togo which is in the sub-saharan africa. Looking at the this, we can see that the countries with the highest happiness score is in Europe and the least happiest scores are for the countries in Africa.

# %%
sns.lmplot(x="Economy (GDP per Capita)", y = 'Freedom', data = df)

# %%
#This shows a positive relationship between economy and freedom which is something which would expect.

# %%
sns.lmplot(x="Family", y = 'Freedom', data = df)

# %%
sns.lmplot(x="Economy (GDP per Capita)", y = 'Family', data = df)

# %%
sns.lmplot(x="Trust (Government Corruption)", y = 'Freedom', data = df)

# %%
sns.lmplot(x="Dystopia Residual", y = 'Family', data = df)

# %%
sns.lmplot(x="Trust (Government Corruption)", y = 'Happiness Score', data = df)

# %%
figure = plt.figure(figsize = (10,8))
sns.countplot(df, y = 'Region', palette = 'tab20')
plt.ylabel("Regions")
plt.xlabel("Counts")
plt.title("Count by Region", size = 18)
plt.show()

# %%
fig = plt.figure(figsize = (12,8))
sns.boxplot(df, y = 'Region', x = "Happiness Score", palette = 'tab20')
plt.title("Happiness by Region", size = 20)
# Out:
# Text(0.5, 1.0, 'Happiness by Region')

# %%
#This shows the happiness by region - we can see that the happiness score is highest for European Region followed by Middle Eastern Region

# %%
fig = plt.figure(figsize = (30,8))
sns.boxplot(df, y = 'Freedom', x = "Region", palette = 'tab20')
plt.title("Freedom scores by Region", size = 20)
# Out:
# Text(0.5, 1.0, 'Freedom scores by Region')

# %%
#Here we can see that by Freedom the second highest score is for the North American Region

# %%
fig = plt.figure(figsize = (30,8))
sns.boxplot(df, y = 'Trust (Government Corruption)', x = "Region", palette = 'tab20')
plt.title("Freedom scores by Region", size = 20)
# Out:
# Text(0.5, 1.0, 'Freedom scores by Region')

# %%
#We can now check for skewness and outliers. Creating a new df with all the numerical values.

# %%
Region_analysis=df.groupby('Region')
Region_analysis['Happiness Score'].describe().sort_values(by='mean', ascending=True).head(10)
# Out:
#                                  count      mean       std    min      25%  \
# Region
# Sub-Saharan Africa                40.0  4.202800  0.609557  2.839  3.75600
# Southern Asia                      7.0  4.580857  0.570526  3.575  4.39250
# Southeastern Asia                  9.0  5.317444  0.950020  3.819  4.87600
# Central and Eastern Europe        29.0  5.332931  0.570446  4.218  4.95900
# Middle East and Northern Africa   20.0  5.406900  1.101382  3.006  4.70775
# Eastern Asia                       6.0  5.626167  0.554053  4.874  5.22350
# Latin America and Caribbean       22.0  6.144682  0.728560  4.518  5.84050
# Western Europe                    21.0  6.689619  0.824582  4.857  6.30200
# North America                      2.0  7.273000  0.217789  7.119  7.19600
# Australia and New Zealand          2.0  7.285000  0.001414  7.284  7.28450
#
#                                    50%      75%    max
# Region
# Sub-Saharan Africa               4.272  4.58075  5.477
# ...

# %%
#This is interesting as the mean shows that Australia and Newzealand has the highest happiness score (mean)

# %%
Family_analysis=df.groupby(['Family','Region'])
Family_analysis['Happiness Score'].describe().sort_values(by='mean', ascending=True).head(10)
# Out:
#                                          count   mean  std    min    25%  \
# Family  Region
# 0.13995 Sub-Saharan Africa                 1.0  2.839  NaN  2.839  2.839
# 0.41587 Sub-Saharan Africa                 1.0  2.905  NaN  2.905  2.905
# 0.47489 Middle East and Northern Africa    1.0  3.006  NaN  3.006  3.006
# 0.35386 Sub-Saharan Africa                 1.0  3.340  NaN  3.340  3.340
# 0.77370 Sub-Saharan Africa                 1.0  3.465  NaN  3.465  3.465
# 0.30285 Southern Asia                      1.0  3.575  NaN  3.575  3.575
# 0.85188 Sub-Saharan Africa                 1.0  3.587  NaN  3.587  3.587
# 0.77115 Sub-Saharan Africa                 1.0  3.655  NaN  3.655  3.655
# 0.46475 Sub-Saharan Africa                 1.0  3.656  NaN  3.656  3.656
# 0.76062 Sub-Saharan Africa                 1.0  3.667  NaN  3.667  3.667
#
#                                            50%    75%    max
# Family  Region
# 0.13995 Sub-Saharan Africa               2.839  2.839  2.839
# ...

# %%
Health_analysis=df.groupby(['Health (Life Expectancy)','Region'])
Health_analysis['Happiness Score'].describe().sort_values(by='mean', ascending=False).head(10)
# Out:
#                                                     count   mean  std    min  \
# Health (Life Expectancy) Region
# 0.94143                  Western Europe               1.0  7.587  NaN  7.587
# 0.94784                  Western Europe               1.0  7.561  NaN  7.561
# 0.87464                  Western Europe               1.0  7.527  NaN  7.527
# 0.88521                  Western Europe               1.0  7.522  NaN  7.522
# 0.90563                  North America                1.0  7.427  NaN  7.427
# 0.88911                  Western Europe               1.0  7.406  NaN  7.406
# 0.89284                  Western Europe               1.0  7.378  NaN  7.378
# 0.91087                  Western Europe               1.0  7.364  NaN  7.364
# 0.90837                  Australia and New Zealand    1.0  7.286  NaN  7.286
# 0.93156                  Australia and New Zealand    1.0  7.284  NaN  7.284
#
#                                                       25%    50%    75%    max
# ...

# %%
Family_analysis=df.groupby(['Family','Trust (Government Corruption)', 'Region'])
Family_analysis['Happiness Score'].describe().sort_values(by='mean', ascending=False).head(10)
# Out:
#                                                                  count   mean  \
# Family  Trust (Government Corruption) Region
# 1.34951 0.41978                       Western Europe               1.0  7.587
# 1.40223 0.14145                       Western Europe               1.0  7.561
# 1.36058 0.48357                       Western Europe               1.0  7.527
# 1.33095 0.36503                       Western Europe               1.0  7.522
# 1.32261 0.32957                       North America                1.0  7.427
# 1.31826 0.41372                       Western Europe               1.0  7.406
# 1.28017 0.31814                       Western Europe               1.0  7.378
# 1.28907 0.43844                       Western Europe               1.0  7.364
# 1.31967 0.42922                       Australia and New Zealand    1.0  7.286
# 1.30923 0.35637                       Australia and New Zealand    1.0  7.284
#
# ...

# %%
Numeric_Df=df[df.columns[2:]]

# %%
Numeric_Df
# Out:
#      Happiness Rank  Happiness Score  Standard Error  \
# 0                 1            7.587         0.03411
# 1                 2            7.561         0.04884
# 2                 3            7.527         0.03328
# 3                 4            7.522         0.03880
# 4                 5            7.427         0.03553
# ..              ...              ...             ...
# 153             154            3.465         0.03464
# 154             155            3.340         0.03656
# 155             156            3.006         0.05015
# 156             157            2.905         0.08658
# 157             158            2.839         0.06727
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                     1.39651  1.34951                   0.94143  0.66557
# 1                     1.30232  1.40223                   0.94784  0.62877
# 2                     1.32548  1.36058                   0.87464  0.64938
# ...

# %%
plt.figure(figsize=(16,18), facecolor='red')
pn =1
for n in Numeric_Df:
    if pn <=9:
        ax = plt.subplot(4,4,pn)
        sns.distplot(Numeric_Df[n], color='b')
        plt.xlabel(n,fontsize=18)
    pn+=1
plt.show()

# %%
Numeric_Df.skew()
# Out:
# Happiness Rank                   0.000418
# Happiness Score                  0.097769
# Standard Error                   1.983439
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# dtype: float64

# %% [markdown]
# #As we can see Standard error has a positive skewness along with Trust and Generosity. This indicates right skewed data (majority of the data points are actually on the left of the mean - Longer tail on the RIGHT SIDE). Other variables such as Economic, Family, Health and Freedom are negatively skewed(majority of the data points are actually on the right of the mean - Longer tail on the LEFT SIDE) Dystopic and Happiness score are quite near to 0 indicating a slighter normal distributions

# %%
cor = Numeric_Df.corr()

# %%
cor
# Out:
#                                Happiness Rank  Happiness Score  \
# Happiness Rank                       1.000000        -0.992105
# Happiness Score                     -0.992105         1.000000
# Standard Error                       0.158516        -0.177254
# Economy (GDP per Capita)            -0.785267         0.780966
# Family                              -0.733644         0.740605
# Health (Life Expectancy)            -0.735613         0.724200
# Freedom                             -0.556886         0.568211
# Trust (Government Corruption)       -0.372315         0.395199
# Generosity                          -0.160142         0.180319
# Dystopia Residual                   -0.521999         0.530474
#
#                                Standard Error  Economy (GDP per Capita)  \
# Happiness Rank                       0.158516                 -0.785267
# Happiness Score                     -0.177254                  0.780966
# ...

# %%
plt.figure(figsize = (18, 14))
sns.heatmap(Numeric_Df.corr(), linewidths = 0.1, fmt = ".2g", linecolor = "pink", annot = True, cmap="Blues_r")
plt.yticks(rotation = 0);
plt.show()

# %%
#Here we can see that Family, life expectancy, economy is highly correlated with happiness score followed by freedom dystopic with moderate skewness and trust and generosity, standard eror shows really less or weak corr

# %%
cor['Happiness Score'].sort_values(ascending = False)
# Out:
# Happiness Score                  1.000000
# Economy (GDP per Capita)         0.780966
# Family                           0.740605
# Health (Life Expectancy)         0.724200
# Freedom                          0.568211
# Dystopia Residual                0.530474
# Trust (Government Corruption)    0.395199
# Generosity                       0.180319
# Standard Error                  -0.177254
# Happiness Rank                  -0.992105
# Name: Happiness Score, dtype: float64

# %%
#This table confirms the above analysis

# %% [markdown]
# It is also worth noting that when I looked into skewness, the standard error showed high skewness but in terms of correlation is not very strong which means it is not a strong predictor for happiness score. I will still reduce skewness in the late steps
#
# For variables like family, health and Economy - It did show some skewness and they are strongly correlated with happiness score.
# For other variables such as trust, freedom and Generosity - they are weakly correlated with happiness which means that these cann have a insignificant impact on the predictive side.

# %%
df['Family'] = np.square(df['Family'])

# %%
print(df['Family'].skew())
# Out:
# -0.2557276286302913

# %%
df['Health (Life Expectancy)'] = np.square(df['Health (Life Expectancy)'])

# %%
print(df['Health (Life Expectancy)'].skew())
# Out:
# -0.014062846673226732

# %%
from scipy.stats import boxcox

# %%
df['Standard Error']=boxcox(df['Standard Error'],0)

# %%
print(df['Standard Error'].skew())
# Out:
# 0.48462318471794924

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
sns.histplot(x='Happiness Score', data=df)
plt.xlabel('Happiness Score')
plt.ylabel('Count')
plt.title('Overall count for happiness score')
plt.show()

# %%
sns.lmplot(x='Family', y='Happiness Score', data=df)
sns.lmplot(x='Health (Life Expectancy)', y='Happiness Score', data=df)
sns.lmplot(x='Freedom', y='Happiness Score', data=df)
sns.lmplot(x='Economy (GDP per Capita)', y='Happiness Score', data=df)

# %%
New_df = df[df.columns[2:]]

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
X=New_df.drop(columns =['Happiness Score'])
Y=New_df['Happiness Score']

# %%
df.replace([np.inf, -np.inf], np.nan, inplace=True) 
df.dropna(inplace=True)

# %%
vif =pd.DataFrame()
vif['vif'] = [variance_inflation_factor(X.values,i) for i in range(X.shape[1])]
vif['Features'] = X.columns

# %%
vif
# Out:
#           vif                       Features
# 0   16.010144                 Happiness Rank
# 1  114.090954                 Standard Error
# 2   23.935693       Economy (GDP per Capita)
# 3   14.467951                         Family
# 4   17.263880       Health (Life Expectancy)
# 5   16.448224                        Freedom
# 6    3.616130  Trust (Government Corruption)
# 7    5.829370                     Generosity
# 8   18.344744              Dystopia Residual

# %%
X.drop("Standard Error", axis = 1, inplace = True)

# %%
vif = pd.DataFrame()
vif["Vif"] = [variance_inflation_factor(X.values, i) for i in range(len(X.columns))]
vif["Features"] = X.columns

vif
# Out:
#          Vif                       Features
# 0   3.285444                 Happiness Rank
# 1  22.779032       Economy (GDP per Capita)
# 2  13.415384                         Family
# 3  14.579889       Health (Life Expectancy)
# 4  15.947627                        Freedom
# 5   3.480267  Trust (Government Corruption)
# 6   5.653606                     Generosity
# 7   9.360197              Dystopia Residual

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
Scaler = StandardScaler()
Scaled_DF = Scaler.fit_transform(New_df)
PrincipalCA = PCA(n_components=0.95) 
PCA_DF = PrincipalCA.fit_transform(Scaled_DF)

# %%
from sklearn.linear_model import LinearRegression 
from sklearn.model_selection import train_test_split, cross_val_score, KFold
from sklearn.metrics import mean_absolute_error,mean_squared_error, r2_score
from sklearn.ensemble import GradientBoostingRegressor

# %%
Highest_Accuracy = 0
True_random_state = 0
for r in range(1,300):
    X_train,X_test,Y_train,Y_test = train_test_split(PCA_DF, Y, test_size = 0.30, random_state=r)
    LinearR = LinearRegression()
    LinearR.fit(X_train, Y_train)
    predictor=LinearR.predict(X_test)
    initialscore = r2_score(Y_test, predictor)
    if initialscore > Highest_Accuracy:
        Highest_Accuracy = initialscore
        True_random_state = r

print(f"True r2 Score: {Highest_Accuracy} at randomstate: {True_random_state}")
# Out:
# True r2 Score: 0.9985087592470869 at randomstate: 298

# %%
LinearR = LinearRegression()
LinearR.fit(X_train, Y_train)
predict_LinearR=LinearR.predict(X_test)
pred_train=LinearR.predict(X_train)
print('r2_score:', r2_score (Y_test, predict_LinearR))
print('r2_score on given training data:',r2_score(Y_train, pred_train)*100)
print('MAE:', mean_absolute_error(Y_test, predict_LinearR))
print('MSE:', mean_squared_error(Y_test, predict_LinearR))
print('RSE:', np.sqrt(mean_squared_error(Y_test, predict_LinearR)))
# Out:
# r2_score: 0.9977048300646649
# r2_score on given training data: 99.68770074131709
# MAE: 0.043688116943754074
# MSE: 0.0030129779648594155
# RSE: 0.05489059996811308

# %%
sns.kdeplot(Y_test, color="blue", label="actual data", shade=True)
sns.kdeplot(predict_LinearR, color="red", label="predicted data", shade=True)
plt.title('Comparing actual data vs predicted data')
plt.xlabel('Value')
plt.ylabel('Density')
plt.legend()
plt.show()

# %%
from sklearn.linear_model import Lasso

# %%
Lasso = Lasso()
Lasso.fit(X_train, Y_train)
predict_Lasso=Lasso.predict(X_test)
pred_train=Lasso.predict(X_train)
print('r2_score:', r2_score (Y_test, predict_Lasso))
print('r2_score on given training data:',r2_score(Y_train, pred_train)*100)
print('MAE:', mean_absolute_error(Y_test, predict_Lasso))
print('MSE:', mean_squared_error(Y_test, predict_Lasso))
print('RSE:', np.sqrt(mean_squared_error(Y_test, predict_Lasso)))
# Out:
# r2_score: 0.7916595527460366
# r2_score on given training data: 77.30212810063068
# MAE: 0.4352412370567274
# MSE: 0.26870461771256254
# RSE: 0.5183672614204745

# %%
sns.kdeplot(Y_test, color="blue", label="actual data", shade=True)
sns.kdeplot(predict_Lasso, color="red", label="predicted data", shade=True)
plt.title('Comparing actual data vs predicted data')
plt.xlabel('Value')
plt.ylabel('Density')
plt.legend()
plt.show()

# %%
rg = Ridge()
rg.fit(X_train, Y_train)
predict_rg=rg.predict(X_test)
pred_train=rg.predict(X_train)
print('r2_score:', r2_score (Y_test, predict_rg))
print('r2_score on given training data:',r2_score(Y_train, pred_train)*100)
print('MAE:', mean_absolute_error(Y_test, predict_rg))
print('MSE:', mean_squared_error(Y_test, predict_rg))
print('RSE:', np.sqrt(mean_squared_error(Y_test, predict_rg)))
# Out:
# r2_score: 0.9967147291610108
# r2_score on given training data: 99.72182074931966
# MAE: 0.04679851629072524
# MSE: 0.004237139050569191
# RSE: 0.06509331033654066

# %%
sns.kdeplot(Y_test, color="blue", label="actual data", shade=True)
sns.kdeplot(predict_rg, color="red", label="predicted data", shade=True)
plt.title('Comparing actual data vs predicted data')
plt.xlabel('Value')
plt.ylabel('Density')
plt.legend()
plt.show()

# %%
from sklearn.neighbors import KNeighborsRegressor as KNN

# %%
KNNmodel = KNN(n_neighbors=5)
KNNmodel.fit(X_train, Y_train)
predict_KNNmodel=KNNmodel.predict(X_test)
pred_train=KNNmodel.predict(X_train)
print('r2_score:', r2_score (Y_test, predict_KNNmodel))
print('r2_score on given training data:',r2_score(Y_train, pred_train)*100)
print('MAE:', mean_absolute_error(Y_test, predict_KNNmodel))
print('MSE:', mean_squared_error(Y_test, predict_KNNmodel))
print('RSE:', np.sqrt(mean_squared_error(Y_test, predict_KNNmodel)))
# Out:
# r2_score: 0.963725700331421
# r2_score on given training data: 96.33794691743635
# MAE: 0.18334375000000008
# MSE: 0.04761898625000001
# RSE: 0.21821774962179408

# %%
sns.kdeplot(Y_test, color="blue", label="actual data", shade=True)
sns.kdeplot(predict_KNNmodel, color="red", label="predicted data", shade=True)
plt.title('Comparing actual data vs predicted data')
plt.xlabel('Value')
plt.ylabel('Density')
plt.legend()
plt.show()

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
decisiontreeR = DecisionTreeRegressor(criterion = 'squared_error')
decisiontreeR.fit(X_train, Y_train)
predict_decisiontreeR=decisiontreeR.predict(X_test)
pred_train=decisiontreeR.predict(X_train)
print('r2_score:', r2_score (Y_test, predict_decisiontreeR))
print('r2_score on given training data:',r2_score(Y_train, pred_train)*100)
print('MAE:', mean_absolute_error(Y_test, predict_decisiontreeR))
print('MSE:', mean_squared_error(Y_test, predict_decisiontreeR))
print('RSE:', np.sqrt(mean_squared_error(Y_test, predict_decisiontreeR)))
# Out:
# r2_score: 0.9070645293532839
# r2_score on given training data: 100.0
# MAE: 0.25765625000000003
# MSE: 0.12200078125
# RSE: 0.34928610228579093

# %%
sns.kdeplot(Y_test, color="blue", label="actual data", shade=True)
sns.kdeplot(predict_decisiontreeR, color="red", label="predicted data", shade=True)
plt.title('Comparing actual data vs predicted data')
plt.xlabel('Value')
plt.ylabel('Density')
plt.legend()
plt.show()

# %%
We can see that the best model is linear regression

# %%
score = cross_val_score(LinearR,X,Y, scoring='r2')
print(score)
print(score.mean())
print("Standard deviation :",score.std())
# Out:
# [0.98370879 0.89585989 0.96496291 0.7315034  0.84414206]
# 0.8840354108786798
# Standard deviation : 0.09108386918855012

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_1 = {'copy_X': [True, False],'fit_intercept': [True, False], 'positive': [True, False]}

# %%
gcv=GridSearchCV(LinearRegression(),param_1,cv=5)
gcv.fit(X_train, Y_train)
# Out:
# GridSearchCV(cv=5, estimator=LinearRegression(),
#              param_grid={'copy_X': [True, False],
#                          'fit_intercept': [True, False],
#                          'positive': [True, False]})

# %%
best_params = gcv.best_params_
print("Perfect Parameters:", best_params)
# Out:
# Perfect Parameters: {'copy_X': True, 'fit_intercept': True, 'positive': False}

# %%
Finalmodel=LinearRegression(copy_X= True, fit_intercept=True, positive=False)

# %%
Finalmodel.fit(X_train, Y_train)
pred=Finalmodel.predict(X_test)
print('r2_score:', r2_score (Y_test, pred))
print('MAE:', mean_absolute_error(Y_test, pred))
print('MSE:', mean_squared_error(Y_test, pred))
print('RSE:', np.sqrt(mean_squared_error(Y_test, pred)))
# Out:
# r2_score: 0.9977048300646649
# MAE: 0.043688116943754074
# MSE: 0.0030129779648594155
# RSE: 0.05489059996811308

# %%
import joblib
filename = 'HappinessData.pkl'
joblib.dump(LinearR, filename)
# Out:
# ['HappinessData.pkl']

# %%
import joblib
LinearR = joblib.load('HappinessData.pkl')
output = LinearR.score(X_test, Y_test)
print(output)
# Out:
# 0.9977048300646649

# %%
TEST=pd.DataFrame([LinearR.predict(X_test)[:]],index=["predicted","actual"])
TEST.head
# Out:
#                  0        1         2         3         4         5   \
# predicted  5.384205  7.36713  3.762219  4.705684  3.915259  6.674913
# actual     5.384205  7.36713  3.762219  4.705684  3.915259  6.674913
#
#                  6         7         8         9   ...        22        23  \
# predicted  3.741356  3.981856  5.224514  6.548513  ...  5.119708  6.119721
# actual     3.741356  3.981856  5.224514  6.548513  ...  5.119708  6.119721
#
#                  24       25        26        27        28        29  \
# predicted  5.459819  6.68547  7.492407  5.927011  4.661857  4.441193
# actual     5.459819  6.68547  7.492407  5.927011  4.661857  4.441193
#
#                  30        31
# predicted  3.633403  4.872636
# actual     3.633403  4.872636
#
# [2 rows x 32 columns]
